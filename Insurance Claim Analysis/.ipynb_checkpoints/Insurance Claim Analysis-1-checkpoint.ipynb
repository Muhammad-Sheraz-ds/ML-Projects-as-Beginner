# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OrdinalEncoder
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import sklearn.metrics as metrics
import seaborn as sns
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import RobustScaler
from sklearn.impute import SimpleImputer

# %%
df = pd.read_csv('insurance_data.csv')
df.sample(10)
# Out:
#       index  PatientID   age  gender   bmi  bloodpressure diabetic  children  \
# 1181   1181       1182  32.0    male  28.6            132       No         0
# 369     369        370  31.0    male  24.1             88      Yes         1
# 582     582        583  27.0    male  35.9             90       No         0
# 213     213        214  35.0    male  20.4             88       No         0
# 384     384        385  41.0  female  26.3             82      Yes         3
# 46       46         47  24.0    male  33.8             89       No         0
# 984     984        985  24.0    male  33.7            101       No         3
# 89       89         90  23.0    male  33.0             80      Yes         1
# 333     333        334  56.0  female  21.9            100      Yes         1
# 164     164        165  52.0  female  28.1             90      Yes         0
#
#      smoker     region     claim
# 1181     No  northeast  30260.00
# 369      No  northwest   5125.22
# 582      No  southeast   8124.41
# 213      No  southwest   3260.20
# 384      No  northwest   5312.17
# 46       No  southeast   1674.63
# 984      No  southeast  15161.53
# 89       No  northwest   1980.07
# 333      No  southeast   4718.20
# 164      No  northwest   2690.11

# %% [markdown]
# # Drop Unnecessary Columns

# %%
df.drop(columns=['index','PatientID'],inplace=True)
df.head()
# Out:
#     age gender   bmi  bloodpressure diabetic  children smoker     region  \
# 0  39.0   male  23.2             91      Yes         0     No  southeast
# 1  24.0   male  30.1             87       No         0     No  southeast
# 2   NaN   male  33.3             82      Yes         0     No  southeast
# 3   NaN   male  33.7             80       No         0     No  northwest
# 4   NaN   male  34.1            100       No         0     No  northwest
#
#      claim
# 0  1121.87
# 1  1131.51
# 2  1135.94
# 3  1136.40
# 4  1137.01

# %% [markdown]
# # How Large data is?

# %%
df.shape
# Out:
# (1340, 9)

# %% [markdown]
# # How Many Null Values

# %%
df.isnull().sum()
# Out:
# age              5
# gender           0
# bmi              0
# bloodpressure    0
# diabetic         0
# children         0
# smoker           0
# region           3
# claim            0
# dtype: int64

# %% [markdown]
# # What type of data is?

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1340 entries, 0 to 1339
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   age            1335 non-null   float64
#  1   gender         1340 non-null   object
#  2   bmi            1340 non-null   float64
#  3   bloodpressure  1340 non-null   int64
#  4   diabetic       1340 non-null   object
#  5   children       1340 non-null   int64
#  6   smoker         1340 non-null   object
#  7   region         1337 non-null   object
#  8   claim          1340 non-null   float64
# dtypes: float64(3), int64(2), object(4)
# memory usage: 94.3+ KB

# %% [markdown]
# # Column Types
#
# - **Numerical** - age,bmi,bloodpressure,claim
# - **Categorical** -gender, diabetic,children,smoker, region

# %% [markdown]
# # UniVariant EDA

# %% [markdown]
# # Age
#
# - **Missing Values**     3
# - **Shape** Binomial
# - **Outliers** No|

# %%
df['age'].describe()
# Out:
# count    1335.000000
# mean       38.078652
# std        11.102924
# min        18.000000
# 25%        29.000000
# 50%        38.000000
# 75%        47.000000
# max        60.000000
# Name: age, dtype: float64

# %%
sns.histplot(df['age'],kde=True)
# Out:
# <AxesSubplot: xlabel='age', ylabel='Count'>

# %% [markdown]
# - Data is almost Normally Distributed
# - Mostly Patience are of age 30 to 35 and 40 to 45

# %%
sns.kdeplot(df['age'],fill=True)
# Out:
# <AxesSubplot: xlabel='age', ylabel='Density'>

# %%
df['age'].fillna(df['age'].mean(),inplace=True)

# %%
df['age'].skew()
# Out:
# 0.11382341584545372

# %%
df['age'].isnull().sum()
# Out:
# 0

# %%
sns.boxplot(df['age'])
# Out:
# <AxesSubplot: >

# %% [markdown]
# - No Outliers

# %% [markdown]
# # BMI
#
# - **Missing Values**     0
# - **Shape** Noraml Distriubution
# - **Outliers** 4 max

# %%
df['bmi'].describe()
# Out:
# count    1340.000000
# mean       30.668955
# std         6.106735
# min        16.000000
# 25%        26.275000
# 50%        30.400000
# 75%        34.700000
# max        53.100000
# Name: bmi, dtype: float64

# %%
sns.histplot(df['bmi'],kde=True)
# Out:
# <AxesSubplot: xlabel='bmi', ylabel='Count'>

# %%
sns.kdeplot(df['bmi'],fill=True)
# Out:
# <AxesSubplot: xlabel='bmi', ylabel='Density'>

# %% [markdown]
# - Normally Distributed

# %%
sns.boxplot(df['bmi'])
# Out:
# <AxesSubplot: >

# %%
upper_limit= df['bmi'].mean()+3*df['bmi'].std()
#lower_limit= df['bmi'].mean()-3*df['bmi'].std()
upper_limit,lower_limit
# Out:
# (48.914135318349636, 12.456561819017942)

# %%
df[df['bmi']>upper_limit].shape
# Out:
# (4, 9)

# %% [markdown]
# - There are 4 outliers in BMI

# %%
df['bmi']= np.where(df['bmi'] >upper_limit,upper_limit,df['bmi'])

# %% [markdown]
# # After Outlier Detection

# %%
sns.boxplot(df['bmi'])
# Out:
# <AxesSubplot: >

# %% [markdown]
# # Blood Pressure
#
# - **Missing Values**     0
# - **Shape** Positive Skewed
# - **Outliers** 4.6 % Outliers

# %%
df['bloodpressure'].describe()
# Out:
# count    1340.000000
# mean       94.157463
# std        11.434712
# min        80.000000
# 25%        86.000000
# 50%        92.000000
# 75%        99.000000
# max       140.000000
# Name: bloodpressure, dtype: float64

# %%
sns.histplot(df['bloodpressure'])
# Out:
# <AxesSubplot: xlabel='bloodpressure', ylabel='Count'>

# %%
sns.kdeplot(df['bloodpressure'],fill=True,color='red')
# Out:
# <AxesSubplot: xlabel='bloodpressure', ylabel='Density'>

# %% [markdown]
# - **Positively Skewed Data in BloodPressure**

# %%
df['bloodpressure'].skew()
# Out:
# 1.4835342102293079

# %%
sns.boxplot(df['bloodpressure'])
# Out:
# <AxesSubplot: >

# %%
iqr = df['bloodpressure'].quantile(0.75) - df['bloodpressure'].quantile(0.25)
upper_limit= df['bloodpressure'].quantile(0.75) + iqr *1.5
df[df['bloodpressure']>upper_limit].shape
# Out:
# (62, 9)

# %%
df[df['bloodpressure']>upper_limit].shape[0]/df.shape[0]*100
# Out:
# 4.626865671641791

# %% [markdown]
# - There are 62 Outliers in BloodPressure Column Which Is 4% OF THE DATA

# %%
df['bloodpressure']= np.where(df['bloodpressure'] >upper_limit,upper_limit,df['bloodpressure'])

# %% [markdown]
# # After Outlier Detection

# %%
sns.boxplot(df['bloodpressure'])
# Out:
# <AxesSubplot: >

# %% [markdown]
# # claim
#
# - **Missing Values**     0
# - **Shape** Positive Skewed
# - **Outliers** 4.6 % Outliers

# %%
df['claim'].describe()
# Out:
# count     1340.000000
# mean     13252.745642
# std      12109.609288
# min       1121.870000
# 25%       4719.685000
# 50%       9369.615000
# 75%      16604.305000
# max      63770.430000
# Name: claim, dtype: float64

# %%
df['claim'].skew()
# Out:
# 1.5167468509489237

# %%
sns.histplot(df['claim'])
# Out:
# <AxesSubplot: xlabel='claim', ylabel='Count'>

# %%
sns.boxplot(df['claim'])
# Out:
# <AxesSubplot: >

# %%
iqr = df['claim'].quantile(0.75) - df['claim'].quantile(0.25)
upper_limit= df['claim'].quantile(0.75) + iqr *1.5
df['claim']= np.where(df['claim'] >upper_limit,upper_limit,df['claim'])

# %%
df[df['claim']>upper_limit].shape[0]/df.shape[0]*100
# Out:
# 0.0

# %% [markdown]
# # After Handling Outliers

# %%
sns.boxplot(df['claim'])
# Out:
# <AxesSubplot: >

# %% [markdown]
# # Catagorical Columns

# %%
sns.catplot(data=df,x='gender',kind='count')

# %%
sns.catplot(data=df,x='diabetic',kind='count')

# %%
sns.catplot(data=df,x='children',kind='count')

# %%
sns.catplot(data=df,x='smoker',kind='count')

# %%
df = df[~df['region'].isnull()]

# %%
sns.catplot(data=df,x='region',kind='count')

# %% [markdown]
# # Bivariant EDA

# %% [markdown]
# # Num to Num
# - Age with bmi
# - Age with bloodpressure
# - Age with claim
# - bmi with claim
# - bmi with bloodpressure
# - bloodpressure with  claim

# %%
df.head(10)
# Out:
#          age gender      bmi  bloodpressure diabetic  children smoker  \
# 0  39.000000   male  23.2000           91.0      Yes         0     No
# 1  24.000000   male  30.1000           87.0       No         0     No
# 2  38.078652   male  33.3000           82.0      Yes         0     No
# 3  38.078652   male  33.7000           80.0       No         0     No
# 4  38.078652   male  34.1000          100.0       No         0     No
# 5  38.078652   male  34.4000           96.0      Yes         0     No
# 6  38.078652   male  37.3000           86.0      Yes         0     No
# 7  19.000000   male  41.1000          100.0       No         0     No
# 8  20.000000   male  43.0000           86.0       No         0     No
# 9  30.000000   male  47.3375           97.0       No         0     No
#
#       region    claim
# 0  southeast  1121.87
# 1  southeast  1131.51
# 2  southeast  1135.94
# 3  northwest  1136.40
# 4  northwest  1137.01
# 5  northwest  1137.47
# 6  northwest  1141.45
# 7  northwest  1146.80
# 8  northwest  1149.40
# 9  northwest  1163.46

# %%
sns.scatterplot(x=df['age'],y=df['bmi'],hue=df['smoker'],style=df['diabetic'])
# Out:
# <AxesSubplot: xlabel='age', ylabel='bmi'>

# %%
sns.scatterplot(x=df['age'],y=df['bloodpressure'],hue=df['smoker'],style=df['diabetic'])
# Out:
# <AxesSubplot: xlabel='age', ylabel='bloodpressure'>

# %%
sns.scatterplot(x=df['age'],y=df['claim'])
# Out:
# <AxesSubplot: xlabel='age', ylabel='claim'>

# %%
sns.scatterplot(x=df['bmi'],y=df['bloodpressure'])
# Out:
# <AxesSubplot: xlabel='bmi', ylabel='bloodpressure'>

# %%
sns.scatterplot(x=df['bmi'],y=df['claim'])
# Out:
# <AxesSubplot: xlabel='bmi', ylabel='claim'>

# %%
sns.scatterplot(x=df['bloodpressure'],y=df['claim'])
# Out:
# <AxesSubplot: xlabel='bloodpressure', ylabel='claim'>

# %%
fig = plt.figure(figsize=(50,35))
ax1=plt.subplot(3,2,1)
ax2=plt.subplot(3,2,2)
ax3=plt.subplot(3,2,3)
ax4=plt.subplot(3,2,4)
ax5=plt.subplot(3,2,5)
ax6=plt.subplot(3,2,6)


sns.scatterplot(x=df['age'],y=df['bmi'],ax=ax1)
sns.scatterplot(x=df['age'],y=df['bloodpressure'],ax=ax2)
sns.scatterplot(x=df['age'],y=df['claim'],ax=ax3)
sns.scatterplot(x=df['bmi'],y=df['bloodpressure'],ax=ax4)
sns.scatterplot(x=df['bmi'],y=df['claim'],ax=ax5)
sns.scatterplot(x=df['bloodpressure'],y=df['claim'],ax=ax6)
# Out:
# <AxesSubplot: xlabel='bloodpressure', ylabel='claim'>

# %% [markdown]
# # Num to Cat

# %%
df
# Out:
#             age  gender      bmi  bloodpressure diabetic  children smoker  \
# 0     39.000000    male  23.2000           91.0      Yes         0     No
# 1     24.000000    male  30.1000           87.0       No         0     No
# 2     38.078652    male  33.3000           82.0      Yes         0     No
# 3     38.078652    male  33.7000           80.0       No         0     No
# 4     38.078652    male  34.1000          100.0       No         0     No
# ...         ...     ...      ...            ...      ...       ...    ...
# 1335  44.000000  female  35.5000           88.0      Yes         0    Yes
# 1336  59.000000  female  38.1000          118.5       No         1    Yes
# 1337  30.000000    male  34.5000           91.0      Yes         3    Yes
# 1338  37.000000    male  30.4000          106.0       No         0    Yes
# 1339  30.000000  female  47.3375          101.0       No         0    Yes
#
#          region      claim
# 0     southeast   1121.870
# 1     southeast   1131.510
# 2     southeast   1135.940
# 3     northwest   1136.400
# 4     northwest   1137.010
# ...         ...        ...
# 1335  northwest  34431.235
# 1336  northeast  34431.235
# 1337  northwest  34431.235
# 1338  southeast  34431.235
# 1339  southeast  34431.235
#
# [1337 rows x 9 columns]

# %%
print(df[df['gender']=='male']['age'].min())
print(df[df['gender']=='male']['age'].max())
# Out:
# 18.0
# 50.0

# %%
df
# Out:
#             age  gender      bmi  bloodpressure diabetic  children smoker  \
# 0     39.000000    male  23.2000           91.0      Yes         0     No
# 1     24.000000    male  30.1000           87.0       No         0     No
# 2     38.078652    male  33.3000           82.0      Yes         0     No
# 3     38.078652    male  33.7000           80.0       No         0     No
# 4     38.078652    male  34.1000          100.0       No         0     No
# ...         ...     ...      ...            ...      ...       ...    ...
# 1335  44.000000  female  35.5000           88.0      Yes         0    Yes
# 1336  59.000000  female  38.1000          118.5       No         1    Yes
# 1337  30.000000    male  34.5000           91.0      Yes         3    Yes
# 1338  37.000000    male  30.4000          106.0       No         0    Yes
# 1339  30.000000  female  47.3375          101.0       No         0    Yes
#
#          region      claim
# 0     southeast   1121.870
# 1     southeast   1131.510
# 2     southeast   1135.940
# 3     northwest   1136.400
# 4     northwest   1137.010
# ...         ...        ...
# 1335  northwest  34431.235
# 1336  northeast  34431.235
# 1337  northwest  34431.235
# 1338  southeast  34431.235
# 1339  southeast  34431.235
#
# [1337 rows x 9 columns]

# %%
sns.histplot(y=df['age'],x=df['gender'])
# Out:
# <AxesSubplot: xlabel='gender', ylabel='age'>

# %% [markdown]
# # Cat to Cat
# - gender with diabetic
# - gender with smoker
# - gender with region
# - diabeticr with smoker
# - diabeticr with region
# - smoker with region

# %%
pd.crosstab(df['gender'],df['diabetic'])
# Out:
# diabetic   No  Yes
# gender
# female    339  323
# male      358  317

# %%
sns.heatmap(pd.crosstab(df['diabetic'],df['gender'],normalize='columns')*100)
# Out:
# <AxesSubplot: xlabel='gender', ylabel='diabetic'>

# %%
pd.crosstab(df['smoker'],df['gender'])
# Out:
# gender  female  male
# smoker
# No         547   516
# Yes        115   159

# %%
sns.heatmap(pd.crosstab(df['smoker'],df['gender'],normalize='columns',)*100)
# Out:
# <AxesSubplot: xlabel='gender', ylabel='smoker'>

# %%
pd.crosstab(df['gender'],df['region'])
# Out:
# region  northeast  northwest  southeast  southwest
# gender
# female        112        164        224        162
# male          119        185        219        152

# %%
sns.heatmap(pd.crosstab(df['gender'],df['region'],normalize='columns')*100)
# Out:
# <AxesSubplot: xlabel='region', ylabel='gender'>

# %%
pd.crosstab(df['children'],df['gender'])
# Out:
# gender    female  male
# children
# 0            289   284
# 1            158   166
# 2            119   121
# 3             77    80
# 4             11    14
# 5              8    10

# %%
sns.heatmap(pd.crosstab(df['children'],df['gender'],normalize='columns')*100)
# Out:
# <AxesSubplot: xlabel='gender', ylabel='children'>

# %%
pd.crosstab(df['diabetic'],df['smoker'])
# Out:
# smoker     No  Yes
# diabetic
# No        559  138
# Yes       504  136

# %%
sns.heatmap(pd.crosstab(df['diabetic'],df['smoker'],normalize='columns',)*100)
# Out:
# <AxesSubplot: xlabel='smoker', ylabel='diabetic'>

# %%
pd.crosstab(df['diabetic'],df['children'])
# Out:
# children    0    1    2   3   4   5
# diabetic
# No        291  179  120  83  13  11
# Yes       282  145  120  74  12   7

# %%
sns.heatmap(pd.crosstab(df['children'],df['diabetic'],normalize='columns',)*100)
# Out:
# <AxesSubplot: xlabel='diabetic', ylabel='children'>

# %%
pd.crosstab(df['diabetic'],df['region'])
# Out:
# region    northeast  northwest  southeast  southwest
# diabetic
# No              110        192        225        170
# Yes             121        157        218        144

# %%
sns.heatmap(pd.crosstab(df['region'],df['diabetic'],normalize='columns')*100)
# Out:
# <AxesSubplot: xlabel='diabetic', ylabel='region'>

# %%
sns.heatmap(pd.crosstab(df['region'],df['diabetic'],normalize='columns')*100)
# Out:
# <AxesSubplot: xlabel='diabetic', ylabel='region'>

# %%
pd.crosstab(df['children'],df['region'])
# Out:
# region    northeast  northwest  southeast  southwest
# children
# 0               105        154        186        128
# 1                57         76        114         77
# 2                37         66         80         57
# 3                25         46         49         37
# 4                 6          6          6          7
# 5                 1          1          8          8

# %%
sns.heatmap(pd.crosstab(df['children'],df['region'],normalize='columns')*100)
# Out:
# <AxesSubplot: xlabel='region', ylabel='children'>

# %%
pd.crosstab(df['children'],df['smoker'])
# Out:
# smoker     No  Yes
# children
# 0         458  115
# 1         263   61
# 2         185   55
# 3         118   39
# 4          22    3
# 5          17    1

# %%
sns.heatmap(pd.crosstab(df['children'],df['smoker'],normalize='columns')*100)
# Out:
# <AxesSubplot: xlabel='smoker', ylabel='children'>

# %%
pd.crosstab(df['smoker'],df['region'])
# Out:
# region  northeast  northwest  southeast  southwest
# smoker
# No            164        291        352        256
# Yes            67         58         91         58

# %%
sns.heatmap(pd.crosstab(df['smoker'],df['region'],normalize='columns')*100)
# Out:
# <AxesSubplot: xlabel='region', ylabel='smoker'>

# %%
df.head(1)
# Out:
#     age gender   bmi  bloodpressure diabetic  children smoker     region  \
# 0  39.0   male  23.2           91.0      Yes         0     No  southeast
#
#      claim
# 0  1121.87

# %%
sns.heatmap(pd.crosstab(df['smoker'],df['gender'],normalize='columns')*100)
# Out:
# <AxesSubplot: xlabel='gender', ylabel='smoker'>

# %%
pd.crosstab(df['gender'],df['smoker'])
# Out:
# smoker   No  Yes
# gender
# female  547  115
# male    516  159

# %%
sns.countplot(x=df['gender'],hue=df['smoker'])
# Out:
# <AxesSubplot: xlabel='gender', ylabel='count'>

# %%
sns.heatmap(pd.crosstab(df['gender'],df['smoker'],normalize='columns')*100)
# Out:
# <AxesSubplot: xlabel='smoker', ylabel='gender'>

# %%
pd.crosstab(df['gender'],df['smoker'],normalize='columns')*100
# Out:
# smoker         No        Yes
# gender
# female  51.458137  41.970803
# male    48.541863  58.029197

# %%
print(df[df['gender']=='female']['bmi'].mean())
print(df[df['gender']=='male']['bmi'].mean())
# Out:
# 30.378115558912388
# 30.936185185185185

# %%
sns.catplot(data=df,x='gender',y='bmi',kind='bar',col='smoker',hue='diabetic')

# %%
df.sample(10)
# Out:
#       age  gender   bmi  bloodpressure diabetic  children smoker     region  \
# 434  42.0    male  34.7           97.0      Yes         2     No  southwest
# 648  32.0    male  37.3           85.0       No         2     No  southeast
# 412  38.0    male  33.6          100.0      Yes         0     No  southeast
# 337  29.0    male  27.1           82.0      Yes         1     No  southwest
# 355  38.0    male  30.1           87.0       No         5     No  southeast
# 866  59.0  female  33.5           97.0       No         2     No  northwest
# 27   30.0    male  17.5           93.0      Yes         0     No  northwest
# 116  49.0  female  28.2           98.0      Yes         0     No  southeast
# 144  37.0  female  30.6           96.0      Yes         0     No  southeast
# 163  28.0    male  38.1           81.0      Yes         0     No  southeast
#
#         claim
# 434   6082.41
# 648   8978.19
# 412   5699.84
# 337   4746.34
# 355   4915.06
# 866  12269.69
# 27    1621.34
# 116   2200.83
# 144   2459.72
# 163   2689.50

# %%
sns.boxplot(x=df['gender'],y=df['bmi'])
# Out:
# <AxesSubplot: xlabel='gender', ylabel='bmi'>

# %%
sns.boxplot(x=df['gender'],y=df['bmi'],hue=df['diabetic'])
# Out:
# <AxesSubplot: xlabel='gender', ylabel='bmi'>

# %%
sns.boxplot(x=df['gender'],y=df['bmi'],hue=df['smoker'])
# Out:
# <AxesSubplot: xlabel='gender', ylabel='bmi'>

# %%
sns.boxplot(x=df['gender'],y=df['bmi'],hue=df['region'])
# Out:
# <AxesSubplot: xlabel='gender', ylabel='bmi'>

# %%
sns.boxplot(x=df['gender'],y=df['bmi'],hue=df['region'])
# Out:
# <AxesSubplot: xlabel='gender', ylabel='bmi'>

# %%
sns.boxplot(x=df['gender'],y=df['bmi'],hue=df['children'])
# Out:
# <AxesSubplot: xlabel='gender', ylabel='bmi'>

# %%
sns.boxplot(x=df['gender'],y=df['bloodpressure'])
# Out:
# <AxesSubplot: xlabel='gender', ylabel='bloodpressure'>

# %%
sns.boxplot(x=df['diabetic'],y=df['bmi'],hue=df['gender'])
# Out:
# <AxesSubplot: xlabel='diabetic', ylabel='bmi'>

# %%
sns.boxplot(x=df['gender'],y=df['bloodpressure'],hue=df['smoker'])
# Out:
# <AxesSubplot: xlabel='gender', ylabel='bloodpressure'>

# %%
sns.boxplot(x=df['gender'],y=df['bloodpressure'],hue=df['diabetic'])
# Out:
# <AxesSubplot: xlabel='gender', ylabel='bloodpressure'>

# %%
sns.boxplot(x=df['gender'],y=df['bloodpressure'],hue=df['children'])
# Out:
# <AxesSubplot: xlabel='gender', ylabel='bloodpressure'>

# %%
sns.boxplot(x=df['gender'],y=df['bloodpressure'],hue=df['smoker'])
# Out:
# <AxesSubplot: xlabel='gender', ylabel='bloodpressure'>

# %%
sns.boxplot(x=df['gender'],y=df['bloodpressure'],hue=df['region'])
# Out:
# <AxesSubplot: xlabel='gender', ylabel='bloodpressure'>

# %%
sns.boxplot(x=df['smoker'],y=df['bloodpressure'],hue=df['gender'])
# Out:
# <AxesSubplot: xlabel='smoker', ylabel='bloodpressure'>

# %%
sns.boxplot(x=df['smoker'],y=df['bmi'],hue=df['diabetic'])
# Out:
# <AxesSubplot: xlabel='smoker', ylabel='bmi'>

# %%
sns.boxplot(x=df['diabetic'],y=df['bloodpressure'],hue=df['gender'])
# Out:
# <AxesSubplot: xlabel='diabetic', ylabel='bloodpressure'>

# %%
df.head(1)
# Out:
#     age gender   bmi  bloodpressure diabetic  children smoker     region  \
# 0  39.0   male  23.2           91.0      Yes         0     No  southeast
#
#      claim
# 0  1121.87

# %%
df[df['smoker']=='Yes']['bloodpressure'].describe()
# Out:
# count    274.000000
# mean     101.490876
# std       12.589930
# min       80.000000
# 25%       91.000000
# 50%      101.000000
# 75%      114.000000
# max      118.500000
# Name: bloodpressure, dtype: float64

# %%
sns.boxplot(x=df['gender'],y=df['claim'])
# Out:
# <AxesSubplot: xlabel='gender', ylabel='claim'>

# %%
sns.boxplot(x=df['gender'],y=df['claim'],hue=df['smoker'])
# Out:
# <AxesSubplot: xlabel='gender', ylabel='claim'>

# %%
sns.boxplot(x=df['gender'],y=df['claim'],hue=df['diabetic'])
# Out:
# <AxesSubplot: xlabel='gender', ylabel='claim'>

# %%
sns.boxplot(x=df['gender'],y=df['claim'],hue=df['children'])
# Out:
# <AxesSubplot: xlabel='gender', ylabel='claim'>

# %%
df.corr()
# Out:
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_16836\1134722465.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#                     age       bmi  bloodpressure  children     claim
# age            1.000000 -0.043043      -0.071309 -0.026165 -0.030582
# bmi           -0.043043  1.000000       0.140977  0.012433  0.159235
# bloodpressure -0.071309  0.140977       1.000000 -0.030587  0.507629
# children      -0.026165  0.012433      -0.030587  1.000000  0.072409
# claim         -0.030582  0.159235       0.507629  0.072409  1.000000

# %%
sns.heatmap(df.corr())
# Out:
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_16836\58359773.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr())
# <AxesSubplot: >

# %%
df.head(1)
# Out:
#     age gender   bmi  bloodpressure diabetic  children smoker     region  \
# 0  39.0   male  23.2           91.0      Yes         0     No  southeast
#
#      claim
# 0  1121.87

# %%
df
# Out:
#             age  gender      bmi  bloodpressure diabetic  children smoker  \
# 0     39.000000    male  23.2000           91.0      Yes         0     No
# 1     24.000000    male  30.1000           87.0       No         0     No
# 2     38.078652    male  33.3000           82.0      Yes         0     No
# 3     38.078652    male  33.7000           80.0       No         0     No
# 4     38.078652    male  34.1000          100.0       No         0     No
# ...         ...     ...      ...            ...      ...       ...    ...
# 1335  44.000000  female  35.5000           88.0      Yes         0    Yes
# 1336  59.000000  female  38.1000          118.5       No         1    Yes
# 1337  30.000000    male  34.5000           91.0      Yes         3    Yes
# 1338  37.000000    male  30.4000          106.0       No         0    Yes
# 1339  30.000000  female  47.3375          101.0       No         0    Yes
#
#          region      claim
# 0     southeast   1121.870
# 1     southeast   1131.510
# 2     southeast   1135.940
# 3     northwest   1136.400
# 4     northwest   1137.010
# ...         ...        ...
# 1335  northwest  34431.235
# 1336  northeast  34431.235
# 1337  northwest  34431.235
# 1338  southeast  34431.235
# 1339  southeast  34431.235
#
# [1337 rows x 9 columns]

# %% [markdown]
# # Feature Engineering

# %%
df=df.drop(columns=['gender','age','children'])
df
# Out:
#           bmi  bloodpressure      claim  region_northwest  region_southeast  \
# 0     23.2000           91.0   1121.870                 0                 1
# 1     30.1000           87.0   1131.510                 0                 1
# 2     33.3000           82.0   1135.940                 0                 1
# 3     33.7000           80.0   1136.400                 1                 0
# 4     34.1000          100.0   1137.010                 1                 0
# ...       ...            ...        ...               ...               ...
# 1335  35.5000           88.0  34431.235                 1                 0
# 1336  38.1000          118.5  34431.235                 0                 0
# 1337  34.5000           91.0  34431.235                 1                 0
# 1338  30.4000          106.0  34431.235                 0                 1
# 1339  47.3375          101.0  34431.235                 0                 1
#
#       region_southwest  smoker_Yes  diabetic_Yes
# 0                    0           0             1
# 1                    0           0             0
# 2                    0           0             1
# 3                    0           0             0
# 4                    0           0             0
# ...                ...         ...           ...
# 1335                 0           1             1
# 1336                 0           1             0
# 1337                 0           1             1
# 1338                 0           1             0
# 1339                 0           1             0
#
# [1337 rows x 8 columns]

# %%
df
# Out:
#           bmi  bloodpressure      claim  region_northwest  region_southeast  \
# 0     23.2000           91.0   1121.870                 0                 1
# 1     30.1000           87.0   1131.510                 0                 1
# 2     33.3000           82.0   1135.940                 0                 1
# 3     33.7000           80.0   1136.400                 1                 0
# 4     34.1000          100.0   1137.010                 1                 0
# ...       ...            ...        ...               ...               ...
# 1335  35.5000           88.0  34431.235                 1                 0
# 1336  38.1000          118.5  34431.235                 0                 0
# 1337  34.5000           91.0  34431.235                 1                 0
# 1338  30.4000          106.0  34431.235                 0                 1
# 1339  47.3375          101.0  34431.235                 0                 1
#
#       region_southwest  smoker_Yes  diabetic_Yes
# 0                    0           0             1
# 1                    0           0             0
# 2                    0           0             1
# 3                    0           0             0
# 4                    0           0             0
# ...                ...         ...           ...
# 1335                 0           1             1
# 1336                 0           1             0
# 1337                 0           1             1
# 1338                 0           1             0
# 1339                 0           1             0
#
# [1337 rows x 8 columns]

# %%
df['claim'].describe()
# Out:
# count     1337.000000
# mean     12481.944080
# std      10143.761844
# min       1121.870000
# 25%       4746.340000
# 50%       9386.160000
# 75%      16657.720000
# max      34431.235000
# Name: claim, dtype: float64

# %%
df.head(1)
# Out:
#     bmi  bloodpressure    claim  region_northwest  region_southeast  \
# 0  23.2           91.0  1121.87                 0                 1
#
#    region_southwest  smoker_Yes  diabetic_Yes
# 0                 0           0             1

# %%
from sklearn.preprocessing import RobustScaler

# %%
df.head()
# Out:
#     bmi  bloodpressure    claim  region_northwest  region_southeast  \
# 0  23.2           91.0  1121.87                 0                 1
# 1  30.1           87.0  1131.51                 0                 1
# 2  33.3           82.0  1135.94                 0                 1
# 3  33.7           80.0  1136.40                 1                 0
# 4  34.1          100.0  1137.01                 1                 0
#
#    region_southwest  smoker_Yes  diabetic_Yes
# 0                 0           0             1
# 1                 0           0             0
# 2                 0           0             1
# 3                 0           0             0
# 4                 0           0             0

# %%
df.head()
# Out:
#     bmi  bloodpressure    claim  region_northwest  region_southeast  \
# 0  23.2           91.0  1121.87                 0                 1
# 1  30.1           87.0  1131.51                 0                 1
# 2  33.3           82.0  1135.94                 0                 1
# 3  33.7           80.0  1136.40                 1                 0
# 4  34.1          100.0  1137.01                 1                 0
#
#    region_southwest  smoker_Yes  diabetic_Yes
# 0                 0           0             1
# 1                 0           0             0
# 2                 0           0             1
# 3                 0           0             0
# 4                 0           0             0

# %%
df= pd.get_dummies(df,columns=['region','smoker','diabetic'],drop_first=True)
df.sample(10)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [152], in <cell line: 1>()
# ----> 1 df= pd.get_dummies(df,columns=['region','smoker','diabetic'],drop_first=True)
#       2 df.sample(10)
#
# File ~\anaconda3\lib\site-packages\pandas\core\reshape\encoding.py:146, in get_dummies(data, prefix, prefix_sep, dummy_na, columns, sparse, drop_first, dtype)
#     144     raise TypeError("Input must be a list-like for parameter `columns`")
#     145 else:
# --> 146     data_to_encode = data[columns]
#     148 # validate prefixes and separator to avoid silently dropping cols
#     149 def check_len(item, name):
#
# File ~\anaconda3\lib\site-packages\pandas\core\frame.py:3813, in DataFrame.__getitem__(self, key)
#    3811     if is_iterator(key):
#    3812         key = list(key)
# -> 3813     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3815 # take() does not accept boolean indexers
#    3816 if getattr(indexer, "dtype", None) == bool:
#
# File ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py:6070, in Index._get_indexer_strict(self, key, axis_name)
#    6067 else:
#    6068     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6070 self._raise_if_missing(keyarr, indexer, axis_name)
#    6072 keyarr = self.take(indexer)
#    6073 if isinstance(key, Index):
#    6074     # GH 42790 - Preserve name from an Index
#
# File ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py:6130, in Index._raise_if_missing(self, key, indexer, axis_name)
#    6128     if use_interval_msg:
#    6129         key = list(key)
# -> 6130     raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    6132 not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
#    6133 raise KeyError(f"{not_found} not in index")
#
# KeyError: "None of [Index(['region', 'smoker', 'diabetic'], dtype='object')] are in the [columns]"

# %%
x = df.drop(columns=['claim'])
y = df['claim']

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.25)

# %%
trsf = ColumnTransformer(transformers=[
    ('standard_scaler',StandardScaler(),['bmi','bloodpressure'])
    
],remainder='passthrough')

#    ('robust_scaler',StandardScaler

# %%
x_train_transform = trsf.fit_transform(x_train)
x_test_transform = trsf.transform(x_test)

# %%
class GDRegressor:
    
    def __init__(self,learning_rate=0.01,epochs=1000):
        
        self.coef_ = None
        self.intercept_ = None
        self.lr = learning_rate
        self.epochs = epochs
        
    def fit(self,X_train,y_train):
        # init your coefs
        self.intercept_ = 0
        self.coef_ = np.ones(X_train.shape[1])
        
        for i in range(self.epochs):
            # update all the coef and the intercept
            y_hat = np.dot(X_train,self.coef_) + self.intercept_
            #print("Shape of y_hat",y_hat.shape)
            intercept_der = -2 * np.mean(y_train - y_hat)
            self.intercept_ = self.intercept_ - (self.lr * intercept_der)
            
            coef_der = -2 * np.dot((y_train - y_hat),X_train)/X_train.shape[0]
            self.coef_ = self.coef_ - (self.lr * coef_der)
        
        print(self.intercept_,self.coef_)
    
    def predict(self,X_test):
        return np.dot(X_test,self.coef_) + self.intercept_

# %%
lr = GDRegressor()

# %%
#lr =LinearRegression()

# %%
lr.fit(x_train_transform,y_train)
# Out:
# 9611.268172635797 [ 1.31319980e+03  2.31780142e+03 -2.31317102e+02 -1.20250124e+03
#  -1.74025821e+02  1.63269120e+04  3.32070589e-01]

# %%
y_pred = lr.predict(x_test_transform)
y_pred
# Out:
# array([ 5933.62507845,  7692.45168764,  9538.94293243,  4320.280817  ,
#         5860.60321387,  4012.47791957,  6129.8107933 , 28541.48910701,
#         6525.81967466, 28897.44084332,  7324.80809637,  9708.94855678,
#         8151.39265027, 25705.72959332,  9922.8590819 ,  6792.45419399,
#         9073.53173284, 13779.79105501, 31835.65107222,  5965.25459655,
#         6498.92005283, 23762.61391286, 31344.38124393,  8681.94881381,
#        32743.42751953, 13598.65365023, 12043.28271652, 10179.59033125,
#        10811.31925606,  9559.81429351,  6660.88551096,  8868.39494802,
#        22770.93181389,  9914.24457163,  4647.27012498, 25100.72233411,
#        27298.21590989,  7539.61099337, 24549.89706342, 24332.99899073,
#         9804.48029126,  9781.01373224, 27600.16361391,  5063.06255511,
#         8412.38636959,  7639.02222619, 13802.33329409,  5465.32728003,
#        28486.77088585,  7807.8891372 , 10798.13808531, 14759.76276716,
#         9521.92381618, 31691.44256676,  9874.37817244,  9540.01283943,
#         7202.16768911, 10349.45548421, 11923.97534361,  6499.83095657,
#         6412.14352678,  9844.70155523, 25983.85075788,  9500.67011004,
#         7170.16454759,  9986.16393326, 25624.66267364,  9581.92351326,
#        11240.67497524,  5046.94922694, 10307.33041699, 22383.50956273,
#        10997.64748631, 10346.96290346, 10199.58338454,  9838.29989783,
#         6153.41805049,  8299.28905487,  7458.35759015,  8600.28964476,
#        31896.2244868 ,  8110.42909058,  6595.14829766, 23476.55579541,
#        28823.16281498, 10647.02812697, 10274.0572744 , 26255.43490932,
#         8914.33070724, 32244.99094393,  6418.76892578,  6531.12840409,
#         8445.30018808,  9087.8100641 , 10368.11822496,  8392.25284492,
#        10653.78910846, 29567.58306191, 13705.12556595,  7244.2512035 ,
#         6859.76133655,  7583.35666412, 23660.12982446,  7734.36236147,
#        10672.63387342, 12630.00509095,  8526.76286903, 31734.99686507,
#         7502.31253862,  6618.56907131, 10803.62883896,  8942.55529917,
#         7135.5798511 , 30943.1200273 , 11943.18454834, 23399.86882588,
#        11576.48807121,  9746.97973228,  6566.22719538, 10086.08519289,
#         4850.62281392,  7539.98884934, 10593.00130049,  8743.58724648,
#        31463.66582265, 11472.91617051,  6117.90903405, 32792.07192134,
#        13742.85704003,  7887.5174478 ,  8243.06768061, 26865.3864582 ,
#         7465.90219343,  7649.22945991,  5790.70533269,  6148.24979244,
#        13004.6240571 ,  9927.05211896,  5848.89282704,  8641.50380824,
#         8795.58747684, 12360.46544092, 10826.33030806, 21795.85860603,
#         8304.23846021, 27890.74257668, 25524.88700106,  7631.33180909,
#         8134.37353402,  8918.21020557,  9957.65817178,  9398.18090597,
#         6712.47997549,  7764.92708824,  7984.88866829, 30501.06809154,
#        31661.95732197, 12577.31261257, 10370.68616939,  9221.7787399 ,
#         7492.03649856,  9615.62032697, 24459.81475653, 10582.02875008,
#         5996.76643745,  8785.16584972, 32031.97748524, 13121.74134153,
#        27661.47509166,  8876.63160233,  9899.10623767, 10011.27923244,
#         6310.4245283 ,  4519.53961422,  8425.37594114, 10902.09295764,
#        10392.46331855, 10413.87602795,  8959.73790777, 12194.11150532,
#         7466.64002984,  9365.79564616,  9060.17772153,  9629.30640887,
#        13815.65493623,  8872.62931114,  3653.97677069,  7189.00931255,
#         9267.18594043, 10474.45455818, 29487.64121259, 14869.41360287,
#         7142.53220502, 10261.76805442, 10423.21006954,  9409.01787389,
#        23686.4963985 , 10069.06096097,  7935.81124715, 14716.97355876,
#        23943.61061949,  8532.07671413,  6877.91916614,  9909.15446813,
#        10655.06829318,  7529.94488119,  8976.94862323,  7781.53597935,
#         7442.29493624, 10779.98372757, 10527.66985302, 10926.82528518,
#        29879.96196803,  8760.82075613, 24785.23413524, 14203.48295321,
#         9806.86175216,  3674.44236595, 16619.37367289,  4634.28055343,
#        32723.75615483,  6892.88443277, 10003.39744291, 28495.95911362,
#        25747.64026715,  6432.85588461, 11803.19272746,  8846.09924474,
#        11312.38505914,  8931.89628748, 27624.87314727,  9385.59710024,
#         8336.03147066, 11570.42360007, 13130.68814917,  8727.66529074,
#         8741.943622  ,  8607.06915812, 24225.94846863,  8197.90212698,
#         6450.20707145,  8130.92705501, 21987.83297874,  8839.47384574,
#         7423.9915196 ,  7060.51371188,  4314.42562359,  7702.85052056,
#         4822.77607796, 12007.41883531,  9654.96305636,  7710.7323101 ,
#         7891.71048486, 25092.6821679 ,  4656.05770259,  6514.44135842,
#         5948.09478213,  4449.63215806,  5377.27156926,  6739.57096975,
#        32388.31133984,  9032.54537896,  7961.25350126,  7408.61602783,
#         7200.33246542,  4982.71493997,  7971.53465698, 11667.98619299,
#        11629.5168825 , 12257.22561082,  9243.22381847, 13014.47642604,
#         9661.00984898, 23516.44498878,  6539.55154193, 32223.21379477,
#         9101.56984123, 10454.32103351, 25046.55992515, 11746.0930454 ,
#         5942.23958872,  6969.92626707, 11101.04247846, 11354.83708129,
#        11140.02076809,  7586.49832604,  8418.92849837,  9879.87850107,
#         7545.51197216, 16837.47723506,  8289.96012895,  8690.18057922,
#        13201.35112027, 23314.40385374, 11105.58611797,  9773.37421618,
#        12617.37038418, 13225.69621386, 12942.05192648, 26833.94342363,
#        30944.49286425, 24725.17927479, 31961.55593427,  6041.00767114,
#         6593.52746736, 10793.61297767,  7933.2890881 ,  6232.0711401 ,
#        21118.05856629,  8467.28661497,  8389.11118299, 13043.24748195,
#         9964.41915328,  7039.13721288,  6373.37963054, 26277.9771484 ,
#         7899.80155211, 32249.60827867, 10586.240319  , 14528.95872607,
#         9196.33137013, 26132.67148242,  8359.83521594, 12259.46148466,
#        11668.31826358,  7255.62951974,  8459.19554771,  7177.63099632,
#        10465.45281395, 20477.18719909,  9735.62421023,  6761.88946722,
#         5187.87025665,  4930.37306404, 29491.48834175])

# %%
import sklearn.metrics as mse

# %%
print('mean_absolute_error',mse.mean_absolute_error(y_test,y_pred))
# Out:
# mean_absolute_error 4462.354092923228

# %%
print('r2_score',mse.r2_score(y_test,y_pred))
# Out:
# r2_score 0.6928147825918289

# %%
output = pd.DataFrame(y_pred,y_test)
output
# Out:
#                      0
# claim
# 2102.26    5933.625078
# 8059.68    7692.451688
# 14474.68   9538.942932
# 1627.28    4320.280817
# 4454.40    5860.603214
# ...                ...
# 15555.19   9735.624210
# 12124.99   6761.889467
# 2103.08    5187.870257
# 12479.71   4930.373064
# 28950.47  29491.488342
#
# [335 rows x 1 columns]

# %%
output['Error'] = output['claim']-output['0']
output
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [237], in <cell line: 1>()
# ----> 1 output['Error'] = output['claim']-output['0']
#       2 output
#
# File ~\anaconda3\lib\site-packages\pandas\core\frame.py:3807, in DataFrame.__getitem__(self, key)
#    3805 if self.columns.nlevels > 1:
#    3806     return self._getitem_multilevel(key)
# -> 3807 indexer = self.columns.get_loc(key)
#    3808 if is_integer(indexer):
#    3809     indexer = [indexer]
#
# File ~\anaconda3\lib\site-packages\pandas\core\indexes\range.py:395, in RangeIndex.get_loc(self, key, method, tolerance)
#     393             raise KeyError(key) from err
#     394     self._check_indexing_error(key)
# --> 395     raise KeyError(key)
#     396 return super().get_loc(key, method=method, tolerance=tolerance)
#
# KeyError: 'claim'
